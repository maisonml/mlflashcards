# %% [markdown]
# # DATA EXPLORATION - STRUCTURED DATA

# %% [markdown]
# ## Agenda
#
# 1. Hypothesis Testing - A/B Experiment
# 2. Dimensionality Reduction with PCA and t-SNE
# 3. Unsupervised Learning with k-Means, k-Medoids, GMM
# 4. Case Studies - PCA and Clustering

# %% [markdown]
# ## 1.1 Hypothesis Testing
#
# ## Sampling
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/ABTest1.png" width=700 height=250 />
#
# ## Significance Testing
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/ABTest2.png" width=700 height=400 />
#
# <br>
# <br>
#
#
# -----------------------------------------------------

# %% [markdown]
# ## 2.1 Dimensionality Reduction or Feature Extraction or Feature Reduction
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/DimensionalityReduction.jpg" width=500 height=700 />
#
# ## 2.2 Feature Reduction
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/FeatureReduction.jpg" width=500 height=700 />
#
# ## 2.3 [Content Page - Dimensionality Reduction](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-4-content-page-dimensionality-reduction)
#
# ## 2.4 [Content Page - The Basics of Vectors and Matrices](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-4-content-page-the-basics-of-linear-algebra)
#
# ## 2.5 [Content Page - Eigenvectors and Eigenvalues](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-4-content-page-eigenvectors-and-eigenvalues)
#
#
# ## 2.6 Principal Component Analysis
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/PrincipalComponentAnalysis.jpg" width=500 height=600 />
#
# ## 2.7 PCA Steps
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/PCASteps.jpg" width=500 height=700 />
#
# ## 2.8 [Content Page - The Covariance Matrix](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-4-content-page-the-covariance-matrix)
#
# ## 2.9 PCA for Dimensionality Reduction
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/PCAforDimensionalityReduction.jpg" width=500 height=700 />
#
#
# ## 2.10 Stochastic Neighbor Embedding (t-SNE)
#
# ## 2.11 [Content Page - Kullback-Leibler (KL) Divergence](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-5-content-page-kullback-leibler-kl-divergence)
#
# -------------------------------------------------------------------

# %% [markdown]
# ## 3.1 [Content Page - Unsupervised Learning](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-6-content-page-unsupervised-learning)
#
# ## 3.2 Unsupervised Learning Clustering
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/UnsupervisedLearningClustering.jpg" width=500 height=700 />
#
# ## 3.3 Types of Clustering
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/TypesofClustering.jpg" width=500 height=700 />
#
# ## 3.4 Applications of Clustering
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/ApplicationsofClustering.jpg" width=500 height=700 />
#
# ## 3.5 k-Means Clustering
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/kMeansClustering.jpg" width=500 height=700 />
#
# ## 3.6 [Content Page - K-means Clustering](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-7-content-page-k-means-clustering)
#
# ## 3.7 Distance Measures
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/DistanceMeasures.jpg" width=500 height=700 />
#
# ## 3.8 Euclidean vs Manhattan Distance
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/EucvsMan.jpeg" width=350 height=350 />
#
# ## 3.9 Chebyshev Distance
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/Chebyshev.png" width=350 height=350 />
#
# ## 3.10 Limitations of Euclidean Distance
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/LimitationsofEuclideanDistance.jpg" width=500 height=400 />
#
# ## 3.11 Importance of Scaling
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/ImportanceofScaling.jpg" width=500 height=700 />
#
# ## 3.12 [Content Page - Distance and Scaling Measures](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-7-content-page-distance-and-scaling-measures)
#
# ## 3.13 Silouhette Coefficient
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/SilouhetteCoeff.jpg" width=500 height=700 />
#
# ## 3.14 Choosing K
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/ChooseK.jpg" width=500 height=700 />
#
# ## 3.15 Pros and Cons of K-Means
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/ProsandCons.jpg" width=500 height=600 />
#
# ## 3.16 Dynamic Clustering
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/DynamicClustering.jpg" width=500 height=400 />

# %% [markdown]
# ## Gaussian Mixture Model
#
# ## [Content Page - Gaussian Mixture Models](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-7-content-page-gaussian-mixture-models)
#
# ## Connectivity Based Clustering
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/ConnectivityBasedClustering.jpg" width=500 height=700 />
#
# ## Hierarchical Clustering
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/HierarchicalClustering.jpg" width=500 height=700 />
#
# ## Cluster Distances
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/ClusterDistances.jpg" width=500 height=700 />
#
# ## [Content Page - Hierarchical Clustering](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-8-content-page-hierarchical-clustering)
#
# ## Cophonetic Correlation
# <img src="https://raw.githubusercontent.com/maisonml/mlflashcards/master/CophoneticCorrelation.jpg" width=500 height=700 />
#
# ## DBSCAN
#
# ## [Content Page - DBSCAN](https://olympus.mygreatlearning.com/courses/88314/pages/1-dot-8-content-page-dbscan)

# %% [markdown]
# ## Case Studies
#
# ### Problem Statement - Education Data Analysis
# ### ​Context
#
# In this case study, we will use the Education dataset which contains information on educational institutes in the USA. The data has various attributes such as number of applications received, enrolments, faculty education, financial aspects and graduation rate of each institute.
#
# ### Objective
#
# The objective of this problem is to reduce the number of features in the dataset by using dimensionality reduction techniques like PCA and extract valuable insights from the exercise.
#
# ### Data Dictionary
#
#
# The Education dataset contains the following information on various colleges in the US:
#
# Names: Names of various universities and colleges
# Apps: Number of applications received
# Accept: Number of applications accepted
# Enroll: Number of new students enrolled
# Top10perc: Percentage of new students from top 10% of Higher Secondary class
# Top25perc: Percentage of new students from top 25% of Higher Secondary class
# F_Undergrad: Number of full-time undergraduate students
# P_Undergrad: Number of part-time undergraduate students
# Outstate: Number of students for whom the particular college or university is out-of-state tuition
# Room_Board: Cost of room and board
# Books: Estimated book costs for a student
# Personal: Estimated personal spending for a student
# PhD: Percentage of faculties with a Ph.D.
# Terminal: Percentage of faculties with terminal degree
# S_F_Ratio: Student/faculty ratio
# perc_alumni: Percentage of alumni who donate
# Expend: The instructional expenditure per student
# Grad_Rate: Graduation rate
